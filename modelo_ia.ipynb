# %% [markdown]
# <a href="https://colab.research.google.com/github/Vitorms085/atividades-resolvidas-gsi073/blob/main/modelo_ia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
from tokenizers import Tokenizer, models, trainers, pre_tokenizers

# %% [markdown]
# # Pré-tokenização

# %%
frase = "O Senhor é justo em todos os seus caminhos e santo em todas as suas obras"

tok_byte = Tokenizer(models.BPE(unk_token="<unk>"))
tok_byte.pre_tokenizer = pre_tokenizers.ByteLevel()
print(tok_byte.pre_tokenizer.pre_tokenize_str(frase))
# Out:
# [('ĠO', (0, 1)), ('ĠSenhor', (1, 8)), ('ĠÃ©', (8, 10)), ('Ġjusto', (10, 16)), ('Ġem', (16, 19)), ('Ġtodos', (19, 25)), ('Ġos', (25, 28)), ('Ġseus', (28, 33)), ('Ġcaminhos', (33, 42)), ('Ġe', (42, 44)), ('Ġsanto', (44, 50)), ('Ġem', (50, 53)), ('Ġtodas', (53, 59)), ('Ġas', (59, 62)), ('Ġsuas', (62, 67)), ('Ġobras', (67, 73))]

# %% [markdown]
# # Treinamento

# %%
corpus = []
with open("/content/frases-treinamento-IA-Deus(unicas).txt", "r") as f:
    corpus = [line.strip() for line in f.readlines()]
# Out:
# ['Deus é o Criador de todas as coisas visíveis e invisíveis', 'O Senhor é justo em todos os seus caminhos e santo em todas as suas obras', 'Deus amou o mundo de tal maneira que deu Seu Filho Unigênito', 'Ele é o Alfa e o Ômega, o princípio e o fim de tudo', 'Em Deus não há sombra de variação, Ele é imutável', 'O Senhor é o nosso refúgio e fortaleza, socorro bem presente', 'Ele conhece os pensamentos e intenções do coração humano', 'Deus é Espírito, e importa que os que O adoram, O adorem em espírito e em verdade', 'A palavra de Deus é viva e eficaz, mais penetrante que espada', 'O Reino de Deus não é comida nem bebida, mas justiça, paz e alegria no Espírito', 'O nosso Deus é um fogo consumidor, temível em santidade', 'O Senhor dos Exércitos é poderoso em batalha e vitorioso', 'Deus é longânimo para conosco, não querendo que ninguém se perca', 'Ele é o Deus que provê, Seu nome é Jeová Jireh', 'A glória de Deus se manifesta na criação e na salvação', 'Deus é bom, e Sua benignidade dura
# ...
